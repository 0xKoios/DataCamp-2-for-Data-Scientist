# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 1. โหลด csv เข้าไปใน Python Pandas

# %%
df = pd.read_csv("glass.csv")

# %% [markdown]
# 2. เขียนโค้ดแสดง หัว10แถว ท้าย10แถว และสุ่ม10แถว

# %%
df.head(10)
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.00     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00     1
# 5  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26     1
# 6  1.51743  13.30  3.60  1.14  73.09  0.58  8.17  0.0  0.00     1
# 7  1.51756  13.15  3.61  1.05  73.24  0.57  8.24  0.0  0.00     1
# 8  1.51918  14.04  3.58  1.37  72.08  0.56  8.30  0.0  0.00     1
# 9  1.51755  13.00  3.60  1.36  72.99  0.57  8.40  0.0  0.11     1

# %%
df.tail(10)
# Out:
#           RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Type
# 204  1.51617  14.95  0.0  2.27  73.30  0.00  8.71  0.67  0.0     7
# 205  1.51732  14.95  0.0  1.80  72.99  0.00  8.61  1.55  0.0     7
# 206  1.51645  14.94  0.0  1.87  73.11  0.00  8.67  1.38  0.0     7
# 207  1.51831  14.39  0.0  1.82  72.86  1.41  6.47  2.88  0.0     7
# 208  1.51640  14.37  0.0  2.74  72.85  0.00  9.45  0.54  0.0     7
# 209  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7

# %% [markdown]
# 3. เช็คว่ามีข้อมูลที่หายไปไหม สามารถจัดการได้ตามความเหมาะสม

# %%
df.isna().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %% [markdown]
# 4. ใช้ info และ describe อธิบายข้อมูลเบื้องต้น

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df.describe().T
# Out:
#       count       mean       std       min        25%       50%        75%  \
# RI    214.0   1.518365  0.003037   1.51115   1.516523   1.51768   1.519157
# Na    214.0  13.407850  0.816604  10.73000  12.907500  13.30000  13.825000
# Mg    214.0   2.684533  1.442408   0.00000   2.115000   3.48000   3.600000
# Al    214.0   1.444907  0.499270   0.29000   1.190000   1.36000   1.630000
# Si    214.0  72.650935  0.774546  69.81000  72.280000  72.79000  73.087500
# K     214.0   0.497056  0.652192   0.00000   0.122500   0.55500   0.610000
# Ca    214.0   8.956963  1.423153   5.43000   8.240000   8.60000   9.172500
# Ba    214.0   0.175047  0.497219   0.00000   0.000000   0.00000   0.000000
# Fe    214.0   0.057009  0.097439   0.00000   0.000000   0.00000   0.100000
# Type  214.0   2.780374  2.103739   1.00000   1.000000   2.00000   3.000000
#
#            max
# RI     1.53393
# Na    17.38000
# Mg     4.49000
# Al     3.50000
# Si    75.41000
# K      6.21000
# Ca    16.19000
# ...

# %% [markdown]
# 5. ใช้ pairplot ดูความสัมพันธ์เบื้องต้นของ features ที่สนใจ

# %%
sns.pairplot(df);

# %% [markdown]
# 6. ใช้ displot เพื่อดูการกระจายของแต่ละคอลัมน์

# %%
for i in df.drop(['Type'], axis=1).columns:
    sns.displot(df[i], kde=True);

# %% [markdown]
# 7. ใช้ heatmap ดูความสัมพันธ์ของคอลัมน์ที่สนใจ

# %%
df_corr = df.corr()
fig, ax = plt.subplots(figsize=(12, 15))

# mask
mask = np.triu(np.ones_like(df_corr, dtype=np.bool))

# adjust mask and df
mask = mask[1:, :-1]
corr = df_corr.iloc[1:,:-1].copy()

# plot heatmap
sns.heatmap(corr, mask=mask, annot=True, fmt=".2f", 
           linewidths=5, cmap='Blues', vmin=-1, vmax=1, 
           cbar_kws={"shrink": .8}, square=True)

# ticks
yticks = [i.upper() for i in corr.index]
xticks = [i.upper() for i in corr.columns]
plt.yticks(plt.yticks()[0], labels=yticks, rotation=0)
plt.xticks(plt.xticks()[0], labels=xticks, rotation=45)

# title
title = 'CORRELATION MATRIX \n'
plt.title(title, loc='left', fontsize=18)
plt.show()

# %% [markdown]
# 8. สร้าง scatter plot ของความสัมพันธ์ที่มี Correlation สูงสุด

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
plt.figure(figsize=(12, 9))
sns.scatterplot(x=df["Ca"], y=df["RI"]);

# %% [markdown]
# 9. สร้าง scatter plot ของความสัมพันธ์ที่มี Correlation ต่ำสุด

# %%
plt.figure(figsize=(12, 9))
sns.scatterplot(x=df["Si"], y=df["RI"]);

# %% [markdown]
# 10. สร้าง histogram ของ feature ที่สนใจ

# %%
# compactness, area, perimeter
for i in ["Ca", "RI", "Si"]:
    fig = plt.figure(figsize=(8,6))
    sns.histplot(df[i]);

# %% [markdown]
# 11. สร้าง box plot ของ features ที่สนใจ

# %%
# compactness, area, perimeter
for i in ["Ca", "RI", "Si"]:
    fig = plt.figure(figsize=(8,6))
    sns.boxplot(x=df["Type"], y=df[i])

# %% [markdown]
# 12. สร้าง train/test split ของข้อมูล สามารถลองทดสอบ 70:30, 80:20, 90:10 ratio ได้ตามใจ

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df, df['Type'], test_size=0.3, random_state=100)

# %% [markdown]
# 13. ทำ Data Visualization อื่นๆ (แล้วแต่เลือก)

# %%
# compactness, area, perimeter
for i in ["Ca", "RI", "Si"]:
    fig = plt.figure(figsize=(8,6))
    sns.scatterplot(x=df["Type"], y=df[i])

# %% [markdown]
# 14. พิจารณาว่าควรทำ Normalization หรือ Standardization หรือไม่ควรทั้งสองอย่าง พร้อมให้เหตุผล
#
# ans: ควรทำเฉพาะ Normalization เพราะว่า Data point ไม่ได้กระจายตัวแบบ normal dist

# %% [markdown]
# 15. เลือกช้อยที่ดีที่สุดจากข้อ 14 (หรือจะทำทุกอันแล้วนำมาเปรียบเทียบก็ได้)

# %% [markdown]
# ### Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max_scaler = MinMaxScaler()

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
feature = min_max_scaler.fit_transform(df.drop(columns=["Type"]))

# %%
df.columns[:-1]
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe'], dtype='object')

# %%
df_feature = pd.DataFrame(feature, columns=df.columns[:-1])

# %%
df_feature
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.432836  0.437594  1.000000  0.252336  0.351786  0.009662  0.308550
# 1    0.283582  0.475188  0.801782  0.333333  0.521429  0.077295  0.223048
# 2    0.220808  0.421053  0.790646  0.389408  0.567857  0.062802  0.218401
# 3    0.285777  0.372932  0.821826  0.311526  0.500000  0.091787  0.259294
# 4    0.275241  0.381955  0.806236  0.295950  0.583929  0.088567  0.245353
# ..        ...       ...       ...       ...       ...       ...       ...
# 209  0.223003  0.512782  0.000000  0.806854  0.500000  0.012882  0.348513
# 210  0.250219  0.630075  0.000000  0.529595  0.580357  0.000000  0.276022
# 211  0.417032  0.545865  0.000000  0.538941  0.644643  0.000000  0.279740
# 212  0.235294  0.548872  0.000000  0.514019  0.678571  0.000000  0.283457
# 213  0.261633  0.526316  0.000000  0.557632  0.633929  0.000000  0.296468
#
#            Ba   Fe
# 0    0.000000  0.0
# 1    0.000000  0.0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_feature, df['Type'], test_size=0.3, random_state=100)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()

# %%
nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
predicted_norm = nb.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, recall_score, precision_score

# %%
confusion_matrix_ = confusion_matrix(y_test, predicted_norm)

# %%
fig = plt.figure(figsize=(10, 5))
sns.heatmap(confusion_matrix_, annot=True, cmap="Pastel1", linewidths=0.5, linecolor="white");
plt.xlabel("Predicted", fontsize=18);
plt.ylabel("Actual", fontsize=18);

# %%
from sklearn.metrics import precision_recall_fscore_support as score
precision, recall, fscore_norm, support = score(y_test, predicted_norm)

# %%
print(">> Score:")
print("--"*20)
print(f"   Accuracy = {accuracy_score(y_test, predicted_norm)}")
print(f"   F1 Score = {fscore_norm}")
print("--"*20)
# Out:
# >> Score:
# ----------------------------------------
#    Accuracy = 0.38461538461538464
#    F1 Score = [0.37209302 0.13793103 0.11111111 0.5        0.75       0.8       ]
# ----------------------------------------

# %% [markdown]
# ### Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
std = StandardScaler()

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
feature = std.fit_transform(df.drop(columns=["Type"]))

# %%
df.columns[:-1]
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe'], dtype='object')

# %%
df_feature = pd.DataFrame(feature, columns=df.columns[:-1])

# %%
df_feature
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.872868  0.284953  1.254639 -0.692442 -1.127082 -0.671705 -0.145766
# 1   -0.249333  0.591817  0.636168 -0.170460  0.102319 -0.026213 -0.793734
# 2   -0.721318  0.149933  0.601422  0.190912  0.438787 -0.164533 -0.828949
# 3   -0.232831 -0.242853  0.698710 -0.310994 -0.052974  0.112107 -0.519052
# 4   -0.312045 -0.169205  0.650066 -0.411375  0.555256  0.081369 -0.624699
# ..        ...       ...       ...       ...       ...       ...       ...
# 209 -0.704815  0.898681 -1.865511  2.881125 -0.052974 -0.640968  0.157088
# 210 -0.500178  1.856097 -1.865511  1.094342  0.529374 -0.763919 -0.392276
# 211  0.754046  1.168721 -1.865511  1.154570  0.995252 -0.763919 -0.364103
# 212 -0.612399  1.193270 -1.865511  0.993960  1.241133 -0.763919 -0.335931
# 213 -0.414363  1.009152 -1.865511  1.275028  0.917606 -0.763919 -0.237327
#
#            Ba        Fe
# 0   -0.352877 -0.586451
# 1   -0.352877 -0.586451
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_feature, df['Type'], test_size=0.3, random_state=100)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()

# %%
nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
predicted_std = nb.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, recall_score, precision_score

# %%
confusion_matrix_ = confusion_matrix(y_test, predicted_std)

# %%
fig = plt.figure(figsize=(10, 5))
sns.heatmap(confusion_matrix_, annot=True, cmap="Pastel1", linewidths=0.5, linecolor="white");
plt.xlabel("Predicted", fontsize=18);
plt.ylabel("Actual", fontsize=18);

# %%
from sklearn.metrics import precision_recall_fscore_support as score
precision, recall, fscore_std, support = score(y_test, predicted_std)

# %%
print(">> Score:")
print("--"*20)
print(f"   Accuracy = {accuracy_score(y_test, predicted_std)}")
print(f"   F1 Score = {fscore_std}")
print("--"*20)
# Out:
# >> Score:
# ----------------------------------------
#    Accuracy = 0.38461538461538464
#    F1 Score = [0.37209302 0.13793103 0.11111111 0.5        0.75       0.8       ]
# ----------------------------------------

# %% [markdown]
# 16. เลือกเฉพาะ features ที่สนใจมาเทรนโมเดล และวัดผลเปรียบเทียบกับแบบ all-features

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
X_train, X_test, y_train, y_test = train_test_split(df_feature[["Mg", "Si", "Ca", "RI"]], df['Type'], test_size=0.3, random_state=100)

# %%
nb = GaussianNB()
nb.fit(X_train, y_train)
predicted = nb.predict(X_test)
confusion_matrix_ = confusion_matrix(y_test, predicted)
fig = plt.figure(figsize=(10, 5))
sns.heatmap(confusion_matrix_, annot=True, cmap="Pastel1", linewidths=0.5, linecolor="white");
plt.xlabel("Predicted", fontsize=18);
plt.ylabel("Actual", fontsize=18);

# %%
from sklearn.metrics import precision_recall_fscore_support as score
precision, recall, fscore_some, support = score(y_test, predicted)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(">> Score:")
print("--"*20)
print(f"   Accuracy = {accuracy_score(y_test, predicted)}")
print(f"   F1 Score = {fscore_some}")
print("--"*20)
# Out:
# >> Score:
# ----------------------------------------
#    Accuracy = 0.49230769230769234
#    F1 Score = [0.57142857 0.24242424 0.         0.625      0.         0.77777778]
# ----------------------------------------

# %% [markdown]
# 17. ทำ Visualization ของค่า F1 Score ระหว่าง ผลลัพธ์ของ Normalization, Standardization ทั้งแบบก่อนและหลังการแบ่งข้อมูล

# %%
value = {'Normalization' : fscore_norm, 
         'Standardization': fscore_std}

# %%
df_all = pd.DataFrame(value)
df_all
# Out:
#    Normalization  Standardization
# 0       0.372093         0.372093
# 1       0.137931         0.137931
# 2       0.111111         0.111111
# 3       0.500000         0.500000
# 4       0.750000         0.750000
# 5       0.800000         0.800000

# %%
df_all[["Normalization", "Standardization"]].plot.bar(figsize=(10, 5));

# %% [markdown]
# 18. สามารถใช้เทคนิคใดก็ได้ตามที่สอนมา ใช้ Naïve Bayesแล้วให้ผลลัพธ์ที่ดีที่สุดที่เป็นไปได้ (ลองปรับ Parameter?)

# %%
df_feature.head()
# Out:
#          RI        Na        Mg        Al        Si         K        Ca  \
# 0  0.872868  0.284953  1.254639 -0.692442 -1.127082 -0.671705 -0.145766
# 1 -0.249333  0.591817  0.636168 -0.170460  0.102319 -0.026213 -0.793734
# 2 -0.721318  0.149933  0.601422  0.190912  0.438787 -0.164533 -0.828949
# 3 -0.232831 -0.242853  0.698710 -0.310994 -0.052974  0.112107 -0.519052
# 4 -0.312045 -0.169205  0.650066 -0.411375  0.555256  0.081369 -0.624699
#
#          Ba        Fe
# 0 -0.352877 -0.586451
# 1 -0.352877 -0.586451
# 2 -0.352877 -0.586451
# 3 -0.352877 -0.586451
# 4 -0.352877 -0.586451

# %%
feature = df_feature[["Mg", "Si", "Ca", "RI"]]
feature.head()
# Out:
#          Mg        Si        Ca        RI
# 0  1.254639 -1.127082 -0.145766  0.872868
# 1  0.636168  0.102319 -0.793734 -0.249333
# 2  0.601422  0.438787 -0.828949 -0.721318
# 3  0.698710 -0.052974 -0.519052 -0.232831
# 4  0.650066  0.555256 -0.624699 -0.312045

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(feature, df['Type'], test_size=0.3, random_state=100)

# %%
from sklearn.model_selection import GridSearchCV

# %%
GaussianNB().get_params()
# Out:
# {'priors': None, 'var_smoothing': 1e-09}

# %%
parameter = {"var_smoothing": [0.0000001, 0.000001, 0.0001, 0.001, 0.01, 0.1]}

# %%
grid_search = GridSearchCV(GaussianNB(), parameter)
grid_search.fit(X_train, y_train)
predicted_norm = grid_search.predict(X_test)
confusion_matrix_ = confusion_matrix(y_test, predicted_norm)
fig = plt.figure(figsize=(10, 5))
sns.heatmap(confusion_matrix_, annot=True, cmap="Pastel1", linewidths=0.5, linecolor="white");
plt.xlabel("Predicted", fontsize=18);
plt.ylabel("Actual", fontsize=18);
precision, recall, fscore_some, support = score(y_test, predicted)
print(">> Score:")
print("--"*20)
print(f"   Accuracy = {accuracy_score(y_test, predicted_norm)}")
print(f"   F1 Score = {fscore_some}")
print(f"   Precision = {precision}")
print(f"   Recall = {recall}")
print("--"*20)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# >> Score:
# ----------------------------------------
#    Accuracy = 0.5076923076923077
#    F1 Score = [0.57142857 0.24242424 0.         0.625      0.         0.77777778]
#    Precision = [0.41025641 0.5        0.         0.71428571 0.         0.7       ]
#    Recall = [0.94117647 0.16       0.         0.55555556 0.         0.875     ]
# ...
