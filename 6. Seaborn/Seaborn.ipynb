# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 1. สร้าง DataFrame ที่เก็บยอดขายของบริษัท A,B,C,D ของปี 2014,2015,2016,2017 โดยชื่อบริษัทเป็น index และปีเป็น column. สร้างคำสั่ง numpy สุ่มเลขแบบ float ให้เป็นรายได้ของบริษัทที่อยู่ในช่วง 50 – 500 (หน่วยล้านบาท)

# %%
company = ["A", "B", "C", "D"]
year = ["2014", "2015", "2016", "2017"]
income = np.random.randint(50, 500, size=(4,4))

# %%
income
# Out:
# array([[244, 245, 304, 362],
#        [169, 327, 347, 489],
#        [263, 196, 325, 332],
#        [223, 461, 292,  53]])

# %%
df = pd.DataFrame(data=income, index=company, columns=year)
df
# Out:
#    2014  2015  2016  2017
# A   244   245   304   362
# B   169   327   347   489
# C   263   196   325   332
# D   223   461   292    53

# %% [markdown]
# ### 2.ใช้ข้อมูลจาก DataFrame ด้านบนสร้าง Bar plot ให้แกน x เป็น ชื่อบริษัท ยอดขายเฉลี่ยเป็นแกน Y โดยสร้างกราฟแบบแนวตั้งและแนวนอน

# %%
df.T.mean()
# Out:
# A    288.75
# B    333.00
# C    279.00
# D    257.25
# dtype: float64

# %%
df.T.describe().T
# Out:
#    count    mean         std    min     25%    50%     75%    max
# A    4.0  288.75   56.316812  244.0  244.75  274.5  318.50  362.0
# B    4.0  333.00  130.975825  169.0  287.50  337.0  382.50  489.0
# C    4.0  279.00   63.429751  196.0  246.25  294.0  326.75  332.0
# D    4.0  257.25  168.930706   53.0  180.50  257.5  334.25  461.0

# %%
sns.barplot(x=df.index, y=df.T.mean());

# %%
sns.barplot(x=df.index, y=df.T.describe().T["mean"]);

# %% [markdown]
# ### 3.ใช้ข้อมูลจาก DataFrame ด้านบนสร้าง Scatter plot ให้แกน x เป็น ชื่อบริษัท ยอดขายปี 2017 เป็นแกน Y โดยสร้างกราฟแบบแนวตั้งและแนวนอน

# %%
sns.scatterplot(x=df.index, y=df["2017"]);

# %% [markdown]
# ### ให้ import ไฟล์ titanic ไฟล์เดิมจากบทเรียน Pandas เข้าสู่ Jupyter Notebook สามารถใช้ Pandas มาร่วมทำด้วย

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 4. สร้าง count plot นับข้อมูล Embarked โดยสร้างกราฟแบบแนวตั้งและแนวนอน

# %%
sns.countplot(x=df["Embarked"]);

# %%
sns.countplot(y=df["Embarked"]);

# %% [markdown]
# ### 5. สร้าง count pot นับข้อมูล Pclass โดยสร้างกราฟแบบแนวตั้งและแนวนอน

# %%
sns.countplot(x=df["Pclass"]);

# %%
sns.countplot(y=df["Pclass"]);

# %% [markdown]
# ### 6. สร้าง box plot ให้แกน X เป็นเพศ และแกน Y เป็นราคา

# %%
sns.boxplot(x=df["Sex"], y=df["Fare"]);

# %% [markdown]
# ### 7. สร้าง box plot ให้แกน X เป็นPclass และแกน Y เป็นราคา

# %%
sns.boxplot(x=df["Pclass"], y=df["Fare"]);

# %% [markdown]
# ### 8. สร้าง barplot โดยให้ แกน X เป็นจุดหมายปลายทางและแกน Y เป็นราคา

# %%
sns.barplot(x=df["Embarked"], y=df["Fare"]);

# %% [markdown]
# ### 9. สร้าง barplot โดยให้ แกน X เป็นPclass และแกน Y เป็นอายุ

# %%
sns.barplot(x=df["Pclass"], y=df["Age"]);

# %% [markdown]
# ### 10. สร้าง Stripplot โดยให้แกน X เป็น Pclass และ แกน Y เป็นราคา

# %%
sns.stripplot(x=df["Pclass"], y=df["Fare"]);

# %% [markdown]
# ### 11. สร้าง Stripplot โดยให้ แกน X เป็น Survived แกน Y เป็นอายุ และ hue เป็นเพศ

# %%
sns.stripplot(x=df["Survived"], y=df["Age"], hue=df["Sex"]);

# %% [markdown]
# ### 12. สร้าง Swarmplot โดยให้ แกน X เป็นเพศและแกน Y เป็นอายุ

# %%
sns.swarmplot(x=df["Sex"], y=df["Age"]);
# Out:
# C:\Users\Jetsukda\anaconda3\lib\site-packages\seaborn\categorical.py:1326: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\Jetsukda\anaconda3\lib\site-packages\seaborn\categorical.py:1330: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %% [markdown]
# ### 13. สร้าง HeatMap โดย crosstab กำหนดให้ index เป็น Pclass และ column เป็นเพศ

# %%
cross = pd.crosstab(index=df["Pclass"], columns=df["Sex"])

# %%
fig = plt.figure(figsize=(12,8))
sns.heatmap(cross, annot=True, cmap="magma_r", robust=True, fmt='.3g', linewidths=1);

# %% [markdown]
# ### 14. สร้าง HeatMap โดย pivot table กำหนดให้ index เป็น Pclass และ column เป็นเพศ และ values เป็น ราคา

# %%
pivot = pd.pivot_table(index="Pclass", columns="Sex", values="Fare", data=df)

# %%
fig = plt.figure(figsize=(12,8))
sns.heatmap(pivot, annot=True, cmap="magma_r", robust=True, fmt='.3g', linewidths=1);

# %% [markdown]
# ### 15. สร้าง HeatMap โดย pivot table กำหนดให้ index เป็น Pclass และ column เป็นเพศ และ values เป็น ราคา และกำหนดเส้นสีขาวขนาด 2 เป็นเส้นแบ่ง

# %%
pivot = pd.pivot_table(index="Pclass", columns="Sex", values="Fare", data=df)

# %%
fig = plt.figure(figsize=(12,8))
sns.heatmap(pivot, annot=True, cmap="magma_r", robust=True, fmt='.3g', linewidths=2);

# %% [markdown]
# ### 16. สร้าง Heatmap โดย Correlation ของทั้ง DataFrame

# %%
corr = df.corr()

# %%
fig = plt.figure(figsize=(15,12))
sns.heatmap(corr, annot=True, cmap="coolwarm", robust=True, fmt='.3g', linewidths=1);

# %% [markdown]
# ### 17. สร้าง Clustermap ของทั้ง DataFrame

# %%
sns.clustermap(corr, annot=True, cmap="coolwarm", robust=True, fmt='.3g', linewidths=1);

# %% [markdown]
# ### 18. พิจารณาจากข้อมูลที่มีความสัมพันธ์มากที่สุดมาสร้าง Scatterplot

# %%
fig = plt.figure(figsize=(15, 10))
sns.scatterplot(x=df["Pclass"], y=df["Fare"]);

# %% [markdown]
# ### 19. พิจารณาจากข้อมูลที่มีความสัมพันธ์น้อยที่สุดมาสร้าง Scatterplot และให้ hue เป็นเพศ

# %%
fig = plt.figure(figsize=(15, 10))
sns.scatterplot(x=df["PassengerId"], y=df["Age"], hue=df["Sex"]);

# %% [markdown]
# ### 20. สร้าง Distribution Plot ของราคาและอายุ

# %%
fig = plt.figure(figsize=(15, 10))
sns.distplot(df[["Age", "Fare"]]);

# %% [markdown]
# ### 21. สร้าง Pair Plot ของทั้ง DataFrame (หรือ column ที่น่าสนใจ)

# %%
sns.pairplot(df[["Age", "Fare", "Survived"]]);
