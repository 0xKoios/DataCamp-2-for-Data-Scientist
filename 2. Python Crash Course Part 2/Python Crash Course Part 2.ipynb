# %% [markdown]
# # Quiz 1

# %% [markdown]
# ### 1) เขียนโปรแกรมรับ input จากผู้ใช้ 1 ตัว แปลงให้เป็น int และตรวจสอบว่าเป็นเลขคู่หรือเลขคี่
#
# 	- หากเป็นเลขคู่ ให้พิมพ์ว่า เลขคู่
#
# 	- หากเป็นเลขคี่ ให้พิมพ์ว่า เลขคี่
#
# 	- หากเป็นเลขศูนย์ให้พิมพ์ว่า เลขศูนย์

# %%
number = int(input("NUMEBER: "))
# Out:
# NUMEBER: 5

# %%
if number == 0:
    print("เลขศูนย์")
elif number % 3 == 0:
    print("เลขคี่")
elif number % 2 == 0:
    print("เลขคู่")

# %% [markdown]
# -----------------

# %% [markdown]
# ### 2. เขียนโปรแกรมรับค่า input 2 ตัว ในรูปแบบ float โดยให้ตัวแรกเป็นตัวตั้ง ตัวที่สองเป็นตัวหาร
#
# 	- หาผลลัพธ์ของการหาร
#
# 	- ใส่เลขทศนิยมได้
#
# 	- ถ้าตัวหารเป็น 0 ให้รับค่าใหม่จนกว่าจะเป็นเลขที่หารได้

# %%
x = float(input("ENTER X: "))
y = float(input("ENTER Y: "))

while y == 0:
    y = float(input("ENTER Y: "))

print("OUTPUI X/Y: ", x/y)
# Out:
# ENTER X: 3
# ENTER Y: 5
# OUTPUI X/Y:  0.6

# %% [markdown]
# ---------------------------

# %% [markdown]
# ### 3. เขียนโปรแกรม infinity while loop โดยรับค่า input มาเรื่อยๆ จนกว่าผู้ใช้จะใส่เลข 0 และนำเลขทั้งหมดมาหาค่าเฉลี่ย

# %%
x = float(input("ENTER X: "))
y = []
while x != 0:
    y.append(x)
    x = float(input("ENTER X: "))

print("Average X:", sum(y)/len(y))
# Out:
# ENTER X: 5
# ENTER X: 6
# ENTER X: 5
# ENTER X: 6
# ENTER X: 4
# ENTER X: 5
# ENTER X: 0
# Average X: 5.166666666666667

# %% [markdown]
# ----------------------------

# %% [markdown]
# ### 4. เขียนโปรมแกรมรับค่า input ที่เป็น integer มาหนึ่งตัว ตรวจสอบว่าเลขนั้นหาร 7 ลงตัวหรือไม่
#
# 	- ถ้าหารลงตัว ให้ปริ้น ‘หาร 7 ลงตัว’
#
# 	 - ถ้าหารไม่ลงตัว ให้ปริ้น ‘หาร 7 ไม่ลงตัว’

# %%
x = int(input("ENTER X: "))

if x % 7 == 0:
    print("หาร 7 ลงตัว")
else:
    print("หาร 7 ไม่ลงตัว")
# Out:
# ENTER X: 21
# หาร 7 ลงตัว

# %% [markdown]
# --------------

# %% [markdown]
# ### 5. เขียนโปรแกรมรับค่า int มา 3 จำนวน และตรวจสอบว่า 3 เลขนั้นสามารถนำมาสร้าง 3 เหลี่ยมมุมฉากได้หรือไม่
#
# ![Rtriangle.png](attachment:Rtriangle.png)

# %%
a = int(input("a = "))
b = int(input("b = "))
c = int(input("c = "))

if c**2 == (a**2) + (b**2):
    print("CAN")
else:
    print("CAN'T")
# Out:
# a = 3
# b = 4
# c = 5
# CAN

# %% [markdown]
# ----------------------

# %% [markdown]
# ### 6. เขียนโปรแกรมรับค่า int มา 3 จำนวน และตรวจสอบว่าเมื่อนำ 3 เลขนั้นมาสร้าง 3 เหลี่ยม จะได้สามเหลี่ยมแบบใด
#
# 	- สามเหลี่ยมมุมแหลม
#
# 	- สามเหลี่ยมมุมป้าน
#
# 	- สามเหลี่ยมมุมฉาก
#
# ![9831655.png](attachment:9831655.png)

# %%
def check_triangle():
    a = int(input("a = "))
    b = int(input("b = "))
    c = int(input("c = "))

    if a == b == c:
        print("Equilateral Triangle")
    elif a == b or b == c or c == b:
        print("Isosceles Triangle")
    elif a != b != c:
        print("Scalane Triangle")

# %%
check_triangle()
# Out:
# a = 1
# b = 1
# c = 2
# Isosceles Triangle

# %%
check_triangle()
# Out:
# a = 1
# b = 1
# c = 1
# Equilateral Triangle

# %%
check_triangle()
# Out:
# a = 3
# b = 4
# c = 5
# Scalane Triangle

# %% [markdown]
# -----------------------

# %% [markdown]
# ### 7. เขียนโปรแกรมให้รับค่าอาหาร 3 ครั้งที่ไปทานอาหารนอกบ้านล่าสุด โดยแต่ละครั้งต้องไม่ต่ำกว่า 1,000 และไม่เกิน 5,000 (ผู้ใช้ต้องใส่อยู่ในช่วงนี้) และนำค่าอาหารทั้ง 3 ครั้งมาบวกกัน หากเกิน 6,000 บาท จะได้รับส่วนลด 15% หากเกิน 12,000 จะได้รับส่วนลด 25% จงหายอดเงินสุดท้ายที่ต้องจ่าย

# %%
def cal_total():
    list_cost = []
    i = 0
    while len(list_cost) < 3:
        cost = int(input("ENTER COST (1000 <= cost < 5000): "))
        if 1000 <= cost < 5000:
            list_cost.append(cost)
            
    if sum(list_cost) > 6000:
        discount = 0.15 * sum(list_cost)
        print("Total : ", sum(list_cost) - discount, "Bath")
    elif sum(list_cost) > 12000:
        discount = 0.25 * sum(list_cost)
        print("Total : ", sum(list_cost) - discount, "Bath")
    else:
        print("Total : ", sum(list_cost), "Bath")

# %%
cal_total()
# Out:
# ENTER COST (1000 <= cost < 5000): 1000
# ENTER COST (1000 <= cost < 5000): 2000
# ENTER COST (1000 <= cost < 5000): 3500
# Total :  5525.0 Bath

# %% [markdown]
# ------------------------

# %% [markdown]
# ### 8. เขียนโปรแกรมให้รับค่าอาหาร 4 ครั้งที่ไปทานอาหารนอกบ้านล่าสุด โดยแต่ละครั้งต้องไม่ต่ำกว่า 1,000 และไม่เกิน 5,000 (ผู้ใช้ต้องใส่อยู่ในช่วงนี้) และนำค่าอาหาร 3 ครั้งแรกมาบวกกัน หากเกิน 6,000 บาท จะได้รับส่วนลด 15% หากเกิน 12,000 จะได้รับส่วนลด 25% ของมื้อที่ 4 จงหายอดเงินสุดท้ายที่ต้องจ่ายของมื้อที่ 4

# %%
def cal_total():
    list_cost = []
    i = 0
    while len(list_cost) < 4:
        cost = int(input("ENTER COST (1000 <= cost < 5000): "))
        if 1000 <= cost < 5000:
            list_cost.append(cost)
    
    if sum(list_cost) > 6000:
        discount = 0.15 * list_cost[3]
        print("Total (only 4) : ",list_cost[3] - discount, "Bath")
        
    elif sum(list_cost) > 12000:
        discount = 0.25 * list_cost[:3]
        print("Total (only 4) : ", list_cost[3] - discount, "Bath")
        
    else:
        print("Total (only 4) : ", list_cost[3], "Bath")

# %%
cal_total()
# Out:
# ENTER COST (1000 <= cost < 5000): 1000
# ENTER COST (1000 <= cost < 5000): 2000
# ENTER COST (1000 <= cost < 5000): 3500
# ENTER COST (1000 <= cost < 5000): 4000
# Total (only 4) :  3400.0 Bath

# %% [markdown]
# -------------------

# %% [markdown]
# ### 10. เขียนโปรแกรมให้รับค่าอาหาร 4 ครั้งที่ไปทานอาหารนอกบ้านล่าสุด โดยแต่ละครั้งต้องไม่ต่ำกว่า 1,000 และไม่เกิน 5,000 (เขียนให้ผู้ใช้ใส่ใหม่หากไม่อยู่ในช่วงที่กำหนด) และถามผู้ใช้มีบัตรเครดิตหรือไม่(True/False) นำค่าอาหาร 3 ครั้งแรกมาบวกกัน หากเกิน 4,000 บาท จะได้รับส่วนลด 25% หากเกิน 9,000 จะได้รับส่วนลด 30% ของมื้อที่ 4 หากมีบัตรเครดิต ลดเพิ่มอีก 5%    จงหายอดเงินสุดท้ายที่ต้องจ่ายของมื้อที่ 4
#
# - 1000 <= cost < 5000
# - credit card ?
#
#     Yes:
#
#     - sum order(1-3) > 4000 -> discount (25%) of order 4 if have credit card discount +5%
#     - sum order(1-3) > 9000 -> discount (30%) of order 4 if have credit card discount +5%

# %%
def cal_total():
    list_cost = []
    i = 0

    while len(list_cost) < 4:
        cost = int(input("ENTER COST (1000 <= cost < 5000): "))
        if 1000 <= cost < 5000:
            list_cost.append(cost)

    credit_card = input("If you have credit cards. discount +5% (Yes/No): ")
    while credit_card != "Yes" and credit_card != "No":
        credit_card = input("If you have credit cards. discount +5% (Yes/No): ")

    if sum(list_cost) > 4000:
        if credit_card == "Yes":
            discount = 0.30 * list_cost[3]
            print("Total (only 4) discount(25% + 5%): ", list_cost[3] - discount, "Bath")
        else:
            discount = 0.25 * list_cost[3]
            print("Total (only 4) discount(25%): ", list_cost[3] - discount, "Bath")

    elif sum(list_cost) > 9000:
        if credit_card == "Yes":
            discount = 0.35 * list_cost[3]
            print("Total (only 4) discount(30% + 5%): ", list_cost[3] - discount, "Bath")
        else:
            discount = 0.30 * list_cost[3]
            print("Total (only 4) discount(30%): ", list_cost[3] - discount, "Bath")

    else:
        print("Total (only 4) : ", list_cost[3], "Bath")

# %%
cal_total()
# Out:
# ENTER COST (1000 <= cost < 5000): 1000
# ENTER COST (1000 <= cost < 5000): 2000
# ENTER COST (1000 <= cost < 5000): 3500
# ENTER COST (1000 <= cost < 5000): 4000
# If you have credit cards. discount +5% (Yes/No): Yes
# Total (only 4) discount(15% + 5%):  3200.0 Bath

# %%
cal_total()
# Out:
# ENTER COST (1000 <= cost < 5000): 1000
# ENTER COST (1000 <= cost < 5000): 2000
# ENTER COST (1000 <= cost < 5000): 3500
# ENTER COST (1000 <= cost < 5000): 4000
# If you have credit cards. discount +5% (Yes/No): No
# Total (only 4) discount(20% + 5%):  3000.0 Bath

# %% [markdown]
# -----------------

# %% [markdown]
# ### 11. จงเขียนโปรแกรมรับ input ที่เป็นประโยคแบบ string ที่มีความยาวของคำไม่ต่ำกว่า 7 ตัวอักษรภาษาอังกฤษ(สมมติว่าเป็นคำเดียว) และมีพิมพ์ใหญ่พิมพ์เล็กปนกัน จากนั้นให้ตรวจสอบแต่ละอักษร ให้แปลงพิมพ์ใหญ่เป็นพิมพ์เล็ก และพิมพ์เล็กเป็นพิมพ์ใหญ่พร้อมกับปริ้นออกมา

# %%
x = input("Enter String (length of string >= 7 and String have Uppercase and Lowercase): ").swapcase()

x
# Out:
# Enter String (length of string >= 7 and String have Uppercase and Lowercase): SSssSS
# 'ssSSss'

# %% [markdown]
# ### 12. เขียนโปรแกรมรับ input 4 ตัวที่เป็น string จากนั้นตรวจสอบว่า input ใดมีความยาวมากที่สุด รองลงมา และน้อยที่สุด จากนั้น ปริ้นแต่ละ input ออกมาตามลำดับน้อยสุดไปมากสุด

# %%
a = input("ENTER STRING 1: ")
b = input("ENTER STRING 2: ")
c = input("ENTER STRING 3: ")
d = input("ENTER STRING 4: ")

input_list = [a, b, c, d]

input_list.sort(key=lambda x: len(x))

print(input_list)
# Out:
# ENTER STRING 1: python
# ENTER STRING 2: R
# ENTER STRING 3: numpy
# ENTER STRING 4: panda
# ['R', 'numpy', 'panda', 'python']

# %% [markdown]
# ---------------------

# %% [markdown]
# ### 13. เขียนโปรแกรมรับ input สองตัวเป็นจำนวนเต็มระหว่าง 0-60 โดยตัวแรกเป็นชั่วโมงและตัวที่สองเป็นนาที คำนวณค่าที่จอดรถถ้าชั่วโมงละ 150 บาท เศษนาทีคิดเป็นนาทีละ 2 บาท

# %%
def calCarsPark():
    hour = int(input("Hour (0-60): "))
    while hour < 0 or hour > 60:
        hour = int(input("Hour (0-60): "))

    minutes = int(input("Minutes (0-60): "))
    while minutes < 0 or minutes > 60:
        minutes = int(input("Minutes (0-60): "))

    minutes_to_hour = int(minutes/60)
    minutes = minutes%60

    # print(hour, minutes_to_hour, minutes)

    hour += minutes_to_hour
    cost = hour*150 + minutes*2

    print("--------------------------")
    print("Hour : ", hour)
    print("Minutes : ", minutes)
    print("Total : ", cost, "Bath")

# %%
calCarsPark()
# Out:
# Hour (0-60): 60
# Minutes (0-60): 20
# --------------------------
# Hour :  60
# Minutes :  20
# Total :  9040 Bath

# %%
calCarsPark()
# Out:
# Hour (0-60): 1
# Minutes (0-60): 45
# --------------------------
# Hour :  1
# Minutes :  45
# Total :  240 Bath

# %% [markdown]
# ---------------------

# %% [markdown]
# ### 14. เขียนโปรแกรมรับ input สองตัวเป็นจำนวนเต็มระหว่าง 0-60 โดยตัวแรกเป็นชั่วโมงและตัวที่สองเป็นนาที คำนวณค่าที่จอดรถถ้าชั่วโมงละ 300 บาท เศษนาทีเกิน 15 นาทีคิดเป็นหนึ่งชั่วโมง หากไม่เกินไม่คิดเงิน และชั่วโมงแรกจอดฟรี

# %%
def calCarPark():
    hour = int(input("Hour (0-60): "))
    while hour < 0 or hour > 60:
        hour = int(input("Hour (0-60): "))

    minutes = int(input("Minutes (0-60): "))
    while minutes < 0 or minutes > 60:
        minutes = int(input("Minutes (0-60): "))

    minutes_to_hour = int(minutes/60)
    minutes = minutes%60

    hour += minutes_to_hour
    if minutes > 15 :
        cost = (hour+1)*300
    else:
        cost = hour*300

    print("--------------------------")
    print("Hour : ", hour)
    print("Minutes : ", minutes)
    print("Total : ", cost, "Bath")

# %%
calCarPark()
# Out:
# Hour (0-60): 2
# Minutes (0-60): 15
# --------------------------
# Hour :  2
# Minutes :  15
# Total :  600 Bath

# %%
calCarPark()
# Out:
# Hour (0-60): 2
# Minutes (0-60): 16
# --------------------------
# Hour :  2
# Minutes :  16
# Total :  900 Bath

# %%
calCarPark()
# Out:
# Hour (0-60): 0
# Minutes (0-60): 10
# --------------------------
# Hour :  0
# Minutes :  10
# Total :  0 Bath

# %% [markdown]
# ------------------

# %% [markdown]
# ### 15. โรงละครสัตว์มีนก กับ วัว และต้องจ่ายภาษีสัตว์ 2 ขา 150 บาทต่อตัว   จ่ายภาษีสัตว์ 4 ขา 220 บาทต่อตัว เขียนโปรแกรมรับค่า input สองตัว ตัวแรกเป็นผลรวมจำนวนหัวของสัตว์ ตัวสองเป็นผลรวมจำนวนขาของสัตว์ จงหาว่าโรงละครสัตว์ต้องจ่ายภาษีเท่าใด
#
# - brid vat 150 bath/brid
# - ox vat 220 bath/ox
#
# input head, leg

# %%
def calVat():
    head = int(input("Head : "))
    leg = int(input("Leg : "))

    # 10 leg -> 4*2 + 2
    ox = round(leg/2 - head)
    if ox < 0:
        ox = 0
    bird = round(head - ox)

    vat = ox*220 + bird*150

    print("-----------------")
    print("Ox :", ox)
    print("Brid:", bird)
    print("Total Vat : ", vat, "Bath")

# %%
calVat()
# Out:
# Head : 3
# Leg : 10
# -----------------
# Ox : 2
# Brid: 1
# Total Vat :  590 Bath

# %%
calVat()
# Out:
# Head : 10
# Leg : 15
# -----------------
# Ox : 0
# Brid: 10
# Total Vat :  1500 Bath

# %%
calVat()
# Out:
# Head : 10
# Leg : 24
# -----------------
# Ox : 2
# Brid: 8
# Total Vat :  1640 Bath
